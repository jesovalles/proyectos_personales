# %% [markdown]
# # Prueba técnica

# %% [markdown]
# A partir de esta información se requiere:
#
# 1.	Predecir cuantas veces será compartido un artículo.
#
# 2.	Analizar y explicar las correlaciones de las variables.
#
# 3.	Detallar los resultados del proceso.
#
# 4.	Se requiere generar mínimo 2 gráficos y su respectivo análisis.

# %%
# importando librerias
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import math
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score
from scipy import stats
from sklearn.tree import DecisionTreeRegressor
import xgboost as xgb
from sklearn import metrics
from sklearn.metrics import mean_absolute_percentage_error
import warnings

warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None) # visualizar todas las columnas

# %% [markdown]
# ## Cargando el dataset

# %%
# creando dataframe
df = pd.read_csv('articulos_ml.csv')
df.head()
# Out:
#                                                Title  \
# 0  What is Machine Learning and how do we use it ...
# 1   10 Companies Using Machine Learning in Cool Ways
# 2  How Artificial Intelligence Is Revolutionizing...
# 3  Dbrain and the Blockchain of Artificial Intell...
# 4  Nasa finds entire solar system filled with eig...
#
#                                                  url  Word count  # of Links  \
# 0  https://blog.signals.network/what-is-machine-l...        1888           1
# 1                                                NaN        1742           9
# 2                                                NaN         962           6
# 3                                                NaN        1221           3
# 4                                                NaN        2039           1
#
#    # of comments  # Images video  Elapsed days  # Shares
# 0            2.0               2            34    200000
# 1            NaN               9             5     25000
# ...

# %%
# visualizando informacion del dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           161 non-null    object
#  1   url             122 non-null    object
#  2   Word count      161 non-null    int64
#  3   # of Links      161 non-null    int64
#  4   # of comments   129 non-null    float64
#  5   # Images video  161 non-null    int64
#  6   Elapsed days    161 non-null    int64
#  7   # Shares        161 non-null    int64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 10.2+ KB

# %% [markdown]
# ## Procesamiento del dataframe

# %%
# eliminando columnas innecesarias
df.drop(columns=['Title', 'url'], inplace=True)
df.head()
# Out:
#    Word count  # of Links  # of comments  # Images video  Elapsed days  \
# 0        1888           1            2.0               2            34
# 1        1742           9            NaN               9             5
# 2         962           6            0.0               1            10
# 3        1221           3            NaN               2            68
# 4        2039           1          104.0               4           131
#
#    # Shares
# 0    200000
# 1     25000
# 2     42000
# 3    200000
# 4    200000

# %%
# rellenando valores faltantes con la media
df['# of comments'] = df['# of comments'].fillna(0)
df.head()
# Out:
#    Word count  # of Links  # of comments  # Images video  Elapsed days  \
# 0        1888           1            2.0               2            34
# 1        1742           9            0.0               9             5
# 2         962           6            0.0               1            10
# 3        1221           3            0.0               2            68
# 4        2039           1          104.0               4           131
#
#    # Shares
# 0    200000
# 1     25000
# 2     42000
# 3    200000
# 4    200000

# %%
# chequeando valores nulos
df.isnull().sum()
# Out:
# Word count        0
# # of Links        0
# # of comments     0
# # Images video    0
# Elapsed days      0
# # Shares          0
# dtype: int64

# %% [markdown]
# ## Análisis Exploratorio de datos

# %% [markdown]
# ### Estadística descríptiva

# %%
# estadistica descriptiva
df.describe().T
# Out:
#                 count          mean           std    min     25%      50%  \
# Word count      161.0   1808.260870   1141.919385  250.0   990.0   1674.0
# # of Links      161.0      9.739130     47.271625    0.0     3.0      5.0
# # of comments   161.0      7.037267     12.269825    0.0     0.0      5.0
# # Images video  161.0      3.670807      3.418290    1.0     1.0      3.0
# Elapsed days    161.0     98.124224    114.337535    1.0    31.0     62.0
# # Shares        161.0  27948.347826  43408.006839    0.0  2800.0  16458.0
#
#                     75%       max
# Word count       2369.0    8401.0
# # of Links          7.0     600.0
# # of comments      10.0     104.0
# # Images video      5.0      22.0
# Elapsed days      124.0    1002.0
# # Shares        35691.0  350000.0

# %% [markdown]
# ### Gráfico de caja

# %%
# obteniendo el nombre de las columnas numericas
num_vars = df.select_dtypes(include=['int', 'float']).columns.tolist()

# creando lienzo con subplots
num_cols = len(num_vars)
num_rows = (num_cols + 2) // 3
fig, axs = plt.subplots(nrows=num_rows, ncols=3, figsize=(15, 5*num_rows))
axs = axs.flatten()

# creando grafico de caja por cada columna
for i, var in enumerate(num_vars):
    sns.boxplot(x=df[var], ax=axs[i])
    axs[i].set_title(var)
    axs[i].set_xlabel('')

# removiendo subplots extras
if num_cols < len(axs):
    for i in range(num_cols, len(axs)):
        fig.delaxes(axs[i])

# adjustando espacio entre subplots
fig.tight_layout()

# mostrando figura
plt.show()

# %% [markdown]
# En primera instancia podemos notar que los datos estan sesgados hacia la izquierda, esto se debe a los valores atípicos en dichos datos.
#
# - Word count = Se puede visualizar que la mayor distribución se encuentra entre las 1000 y 2500 palabras por registro.
# - N° of links= El número de links por registro es bajo, rondando los 10, además que se puede visualizar valores atípicos que están sesgando mi análisis.
# - N° of comments = El mayor margen de comentarios ronda entre los registros sin comentarios y los registros que tiene alrededor de 15 comentarios.
# - N° Images video = Las imagenes por registro rondan entre 0 y 5 en su gran mayoría.
# - Elapsed days = Los elapsed days rondan entre los 30 y 150 días, con ciertos valores atípicos.
# - N° Shares= Los shares tienen su mayor distribucuón entre los no compartidos y los 450k.
#
# Debido a los valores atípicos, procederemos a realizar el método de Z-score para eliminarlos.

# %% [markdown]
# ### Gráfico de distribucuón

# %%
# obteniendo el nombre de las columnas numericas
int_vars = df.select_dtypes(include=['int', 'float']).columns.tolist()

# creando lienzo con subplots
num_cols = len(int_vars)
num_rows = (num_cols + 2) // 3
fig, axs = plt.subplots(nrows=num_rows, ncols=3, figsize=(15, 5*num_rows))
axs = axs.flatten()

# creando historigrama por cada columna
for i, var in enumerate(int_vars):
    df[var].plot.hist(ax=axs[i])
    axs[i].set_title(var)

# removiendo subplots extras
if num_cols < len(axs):
    for i in range(num_cols, len(axs)):
        fig.delaxes(axs[i])

# adjustando espacio entre subplots
fig.tight_layout()

# mostrando figura
plt.show()

# %% [markdown]
# Con este gráfico de distribución podemos corroborar ciertamente el grado de sesgo en la distribución y los datos atípicos. Procederemos a eliminarlos con Z-score.

# %% [markdown]
# ## Análisis de correlación

# %%
# matriz de correlacion
correlation_matrix = df.corr()

# mapa de calor
plt.figure(figsize=(15, 6))
matrix = np.triu(correlation_matrix.corr())
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5, fmt='.2f', mask=matrix)
plt.title("Matriz de correlación - Heatmap")
plt.show()

# grafico de correlacion con respecto a la variable a predecir
# ordenamos los valores de la correlacion
target_corr = correlation_matrix['# Shares'].drop('# Shares')
target_corr_sorted = target_corr.sort_values(ascending=False)

# creamos un mapa de calor con las correlaciones y la variable objetivo
sns.set(font_scale=0.8)
sns.set_style("white")
sns.set_palette("PuBuGn_d")
sns.heatmap(target_corr_sorted.to_frame(), cmap="coolwarm", annot=True, fmt='.2f')
plt.title("Correlación con el # Shares")
plt.show()

# %% [markdown]
# En este caso usamos el coeficiente de correlación de pearson debido a la naturaleza de los datos. Ahora a nivel general podemos visualizar que las correlaciones más fuertes las tienen la cantidad de palabras con el número de imagenes del registro y el número de links, puede decirse que al haber más archivos en el registro, existe más explicación en el campo y por lo tanto influye en la cantidad de palabras, además tiene una correlación medianamente negativa con la variable Elapsed days. La demás variables tiene correlaciones débiles a excepción de la variable a predecir # Shares que tiene unas correlaciones medianamente positivas con las variables # links, # of comments y Elapsed days, se puede deducir que mientras mas links, comentarios y tenga bastante tiempo creado el archivo, más veces será compartido.

# %% [markdown]
# ## Train Test Split

# %%
X = df.drop('# Shares', axis=1)
y = df['# Shares']

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2,random_state=0)

# %% [markdown]
# ### Removiendo Outliers con Z-Score

# %%
# seleccionando columna a la cual no se le removeran outliers
columns_to_keep_outliers = ['# Shares']

# definiendo el umbral de detección de valores atípicos
threshold = 3

# seleccionando columnas numericas
numerical_columns = X_train.select_dtypes(include=['int', 'float']).columns

# recorriendo las columnas numéricas y eliminando los valores atípicos de las columnas
for col in numerical_columns:
    if col not in columns_to_keep_outliers:
        z_scores = np.abs(stats.zscore(X_train[col]))
        outlier_indices = np.where(z_scores > threshold)[0]
        X_train = X_train.drop(X_train.index[outlier_indices])
        y_train = y_train.drop(y_train.index[outlier_indices])

# %% [markdown]
# ## Modelos predictivos

# %% [markdown]
# ### Decision Tree Regressor

# %%
# creando Decision Tree Regressor
dtree = DecisionTreeRegressor()

# Definiendo los hiperparámetros a ajustar y sus valores
param_grid = {
    'max_depth': [2, 4, 6, 8],
    'min_samples_split': [2, 4, 6, 8],
    'min_samples_leaf': [1, 2, 3, 4],
    'max_features': ['auto', 'sqrt', 'log2'],
    'random_state': [0, 42]
}

# creando GridSearchCV
grid_search = GridSearchCV(dtree, param_grid, cv=5, scoring='neg_mean_squared_error')

# entrenando el GridSearchCV con la data de entrenamiento
grid_search.fit(X_train, y_train)

# imprimiendo los mejores hiperparametros
print(grid_search.best_params_)
# Out:
# {'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'random_state': 42}

# %%
# ajustando el Decision Tree Regressor 
dtree = DecisionTreeRegressor(random_state=42, max_depth=2, max_features='sqrt', min_samples_leaf=4, min_samples_split=2)
# entrenando el modelo
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=2, max_features='sqrt', min_samples_leaf=4,
#                       random_state=42)

# %%
# creando las predicciones
y_pred = dtree.predict(X_test)

# %% [markdown]
# ### Evaluación del modelo

# %%
mae = metrics.mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
r2 = metrics.r2_score(y_test, y_pred)
rmse = math.sqrt(mse)

print('MAE is {}'.format(mae))
print('MAPE is {}'.format(mape))
print('MSE is {}'.format(mse))
print('R2 score is {}'.format(r2))
print('RMSE score is {}'.format(rmse))
# Out:
# MAE is 17560.354134956877
# MAPE is 4.1214891090487286e+18
# MSE is 488838189.8075997
# R2 score is 0.20316971007234064
# RMSE score is 22109.68542986534

# %% [markdown]
# ### Importancia de las caracteristicas

# %%
imp_df = pd.DataFrame({
    "Feature Name": X_train.columns,
    "Importance": dtree.feature_importances_
})
fi = imp_df.sort_values(by="Importance", ascending=False)

fi2 = fi.head(10)
plt.figure(figsize=(10,4))
sns.barplot(data=fi2, x='Importance', y='Feature Name')
plt.title('Importancia de caracteristica (Decision Tree Regressor)', fontsize=18)
plt.xlabel ('Importancia', fontsize=16)
plt.ylabel ('Caracteristica', fontsize=16)
plt.show()

# %% [markdown]
# ## XGBoost Regressor

# %%
# creando XGBoost Regressor
xgb_model = xgb.XGBRegressor()

# definiendo hiperparametros para el XGBoost
param_grid = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.2],
    'n_estimators': [100, 200, 300],
    'subsample': [0.8, 1.0],
    'random_state': [0, 42]

}
# creando GridSearchCV
grid_search = GridSearchCV(xgb_model, param_grid, cv=5, scoring='r2')

# entrenando GridSearchCV con los datos de entrenamiento
grid_search.fit(X_train, y_train)

# imprimiendo mejores hiperparametros
print("Best hyperparameters: ", grid_search.best_params_)
# Out:
# Best hyperparameters:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'random_state': 0, 'subsample': 0.8}

# %%
# ajustando el modelo
xgb_model = xgb.XGBRegressor(max_depth=3, learning_rate=0.1, n_estimators=100, random_state=0, subsample=0.8)
# entrenando el modelo
xgb_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=0, ...)

# %%
# creando predicciones
y_pred = xgb_model.predict(X_test)

# %% [markdown]
# ### Evaluación del modelo

# %%
mae = metrics.mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
r2 = metrics.r2_score(y_test, y_pred)
rmse = math.sqrt(mse)

print('MAE is {}'.format(mae))
print('MAPE is {}'.format(mape))
print('MSE is {}'.format(mse))
print('R2 score is {}'.format(r2))
print('RMSE score is {}'.format(rmse))
# Out:
# MAE is 21114.647423946495
# MAPE is 3.133429551818422e+18
# MSE is 677352871.7826015
# R2 score is -0.10411849249809157
# RMSE score is 26026.003761288466

# %% [markdown]
# ### Importancia de las caracteristicas

# %%
imp_df = pd.DataFrame({
    "Feature Name": X_train.columns,
    "Importance": xgb_model.feature_importances_
})
fi = imp_df.sort_values(by="Importance", ascending=False)

fi2 = fi.head(10)
plt.figure(figsize=(10,4))
sns.barplot(data=fi2, x='Importance', y='Feature Name')
plt.title('Importancia de caracteristica (XGBoost Regressor)', fontsize=18)
plt.xlabel ('Importancia', fontsize=16)
plt.ylabel ('Caracteristica', fontsize=16)
plt.show()

# %% [markdown]
# ## Modelo de predicción

# %%
def prediccion_precio (data):
    input_data_as_numpy_array= np.asarray(data)

    input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

    prediction = dtree.predict(input_data_reshaped)
    
    print(f"El artículo se compartirá {prediction[0]:.2f} veces")

# %%
datos = (1888,1,2.0,2,34)
prediccion_precio(datos)
# Out:
# El artículo se compartirá 30200.10 veces

# %% [markdown]
# ## Conclusión

# %% [markdown]
# Para este problema de regresión, luego de evaluar los modelos de arbol de decisión y el modelo de xgb, obtuvimos que el arbol de decisión tuvo un mejor rendimiento a la hora de realizar la evaluación. El modelo de árbol de decisión exhibe un menor error promedio tanto en términos absolutos (MAE) como en cuadrados (MSE), lo que indica una mejor precisión en las predicciones. Además, tiene un coeficiente de determinación (R2 score) más alto, lo que sugiere una mejor capacidad para explicar la variabilidad en los datos. También presenta un RMSE más bajo, indicando una menor dispersión entre las predicciones y los valores reales en la misma escala que los datos originales.
#
# Por lo tanto, basándonos en estas métricas, podemos concluir que, para este conjunto de datos y este problema específico, el modelo de árbol de decisión ofrece un mejor rendimiento en comparación con el modelo XGBoost. Sin embargo, sería importante tener en cuenta otros factores, como la interpretabilidad del modelo, el tiempo de entrenamiento y la escalabilidad, antes de tomar una decisión final sobre qué modelo usar en producción.
