# %% [markdown]
# # Wine Quality Prediction

# %%
#importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
import warnings

warnings.filterwarnings('ignore')
pd.options.display.float_format = '{:,.2f}'.format

# %%
# loading the dataset
df = pd.read_csv('winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           7.40              0.70         0.00            1.90       0.08
# 1           7.80              0.88         0.00            2.60       0.10
# 2           7.80              0.76         0.04            2.30       0.09
# 3          11.20              0.28         0.56            1.90       0.07
# 4           7.40              0.70         0.00            1.90       0.08
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                11.00                 34.00     1.00 3.51       0.56
# 1                25.00                 67.00     1.00 3.20       0.68
# 2                15.00                 54.00     1.00 3.26       0.65
# 3                17.00                 60.00     1.00 3.16       0.58
# 4                11.00                 34.00     1.00 3.51       0.56
#
#    alcohol  quality
# 0     9.40        5
# 1     9.80        5
# 2     9.80        5
# ...

# %%
print(f'This dataset contains {df.shape[0]} rows and {df.shape[1]} columns')
# Out:
# This dataset contains 1599 rows and 12 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
# checking for null values
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# Descriptive statistics
df.describe().T
# Out:
#                         count  mean   std  min   25%   50%   75%    max
# fixed acidity        1,599.00  8.32  1.74 4.60  7.10  7.90  9.20  15.90
# volatile acidity     1,599.00  0.53  0.18 0.12  0.39  0.52  0.64   1.58
# citric acid          1,599.00  0.27  0.19 0.00  0.09  0.26  0.42   1.00
# residual sugar       1,599.00  2.54  1.41 0.90  1.90  2.20  2.60  15.50
# chlorides            1,599.00  0.09  0.05 0.01  0.07  0.08  0.09   0.61
# free sulfur dioxide  1,599.00 15.87 10.46 1.00  7.00 14.00 21.00  72.00
# total sulfur dioxide 1,599.00 46.47 32.90 6.00 22.00 38.00 62.00 289.00
# density              1,599.00  1.00  0.00 0.99  1.00  1.00  1.00   1.00
# pH                   1,599.00  3.31  0.15 2.74  3.21  3.31  3.40   4.01
# sulphates            1,599.00  0.66  0.17 0.33  0.55  0.62  0.73   2.00
# alcohol              1,599.00 10.42  1.07 8.40  9.50 10.20 11.10  14.90
# quality              1,599.00  5.64  0.81 3.00  5.00  6.00  6.00   8.00

# %% [markdown]
# ## Data preprocessing

# %%
df['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
df['quality'] = df['quality'].apply(lambda x: 1 if x >= 7 else 0)
df.rename(columns={'quality': 'good-quality'}, inplace=True)
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           7.40              0.70         0.00            1.90       0.08
# 1           7.80              0.88         0.00            2.60       0.10
# 2           7.80              0.76         0.04            2.30       0.09
# 3          11.20              0.28         0.56            1.90       0.07
# 4           7.40              0.70         0.00            1.90       0.08
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                11.00                 34.00     1.00 3.51       0.56
# 1                25.00                 67.00     1.00 3.20       0.68
# 2                15.00                 54.00     1.00 3.26       0.65
# 3                17.00                 60.00     1.00 3.16       0.58
# 4                11.00                 34.00     1.00 3.51       0.56
#
#    alcohol  good-quality
# 0     9.40             0
# 1     9.80             0
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='good-quality', data=df)
plt.xlabel('Good Quality')
plt.ylabel('Count')
plt.title('Count of Good vs Bad Quality Wines')
plt.show()

# %% [markdown]
# #### Analysis of coorelation between features

# %%
plt.figure(figsize=(6,4))
df.corr()['good-quality'][:-1].sort_values().plot(kind='bar')
plt.xticks(rotation=75)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=True, fmt=".2f")
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# ## Train Test Split

# %%
X = df.drop('good-quality', axis=1)
Y = df['good-quality']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### Logistic Regression

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, y_train)

print(f'Accuracy on Training data : {training_data_accuracy *100:.2f}%')
# Out:
# Accuracy on Training data : 88.29%

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, y_test)

print(f'Accuracy on Test data : {test_data_accuracy *100:.2f}%')
# Out:
# Accuracy on Test data : 86.88%

# %% [markdown]
# ### Support Vector Machine (SVM)

# %%
model2 = svm.SVC(kernel='rbf')

# %%
model2.fit(X_train, y_train)
# Out:
# SVC()

# %%
# accuracy score on training data
X_train_prediction2 = model2.predict(X_train)
training_data_accuracy2 = accuracy_score(X_train_prediction2,y_train)

print(f'Accuracy on Training data : {training_data_accuracy2 *100:.2f}%')
# Out:
# Accuracy on Training data : 86.68%

# %%
# accuracy score on test data
X_test_prediction2 = model2.predict(X_test)
test_data_accuracy2 = accuracy_score(X_test_prediction2,y_test)

print(f'Accuracy on Test data : {test_data_accuracy2 *100:.2f}%')
# Out:
# Accuracy on Test data : 86.25%

# %% [markdown]
# ### Decision Tree

# %%
model3 = DecisionTreeClassifier()

# %%
model3.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# accuracy score on training data
X_train_prediction3 = model3.predict(X_train)
training_data_accuracy3 = accuracy_score(X_train_prediction3,y_train)

print(f'Accuracy on Training data : {training_data_accuracy3 *100:.2f}%')
# Out:
# Accuracy on Training data : 100.00%

# %%
# accuracy score on test data
X_test_prediction3 = model3.predict(X_test)
test_data_accuracy3 = accuracy_score(X_test_prediction3,y_test)

print(f'Accuracy on Test data : {test_data_accuracy3 *100:.2f}%')
# Out:
# Accuracy on Test data : 86.67%

# %% [markdown]
# ### K-Nearest Neighbors (KNN)

# %%
model4 = KNeighborsClassifier(n_neighbors=5)

# %%
model4.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# accuracy score on training data
X_train_prediction4 = model4.predict(X_train)
training_data_accuracy4 = accuracy_score(X_train_prediction4,y_train)

print(f'Accuracy on Training data : {training_data_accuracy4 *100:.2f}%')
# Out:
# Accuracy on Training data : 90.80%

# %%
# accuracy score on test data
X_test_prediction4 = model4.predict(X_test)
test_data_accuracy4 = accuracy_score(X_test_prediction4,y_test)

print(f'Accuracy on Test data : {test_data_accuracy4 *100:.2f}%')
# Out:
# Accuracy on Test data : 85.83%

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# ### Logistic Regression

# %%
# logistic regression model evaluation
sns.heatmap(confusion_matrix(y_test, X_test_prediction), annot=True, fmt="d", cmap='Blues')
plt.ylabel('Predicted Values')
plt.xlabel('Actual Values')
plt.title('Confusion Matrix for Logistic Regression')
plt.show()

print(f'Logistic Regression Model Accuracy: {accuracy_score(y_test, X_test_prediction)*100:.2f}%')
print(f'Logistic Regression Model f1 score: {metrics.f1_score(y_test, X_test_prediction)*100:.2f}%')
print(f'Logistic Regression Model MAE: {metrics.mean_absolute_error(y_test, X_test_prediction)*100:.2f}%')
print(f'Logistic Regression Model RMSE: {np.sqrt(metrics.mean_squared_error(y_test, X_test_prediction))*100:.2f}%')
# Out:
# Logistic Regression Model Accuracy: 86.88%
# Logistic Regression Model f1 score: 30.77%
# Logistic Regression Model MAE: 13.12%
# Logistic Regression Model RMSE: 36.23%

# %% [markdown]
# ### Support Vector Machine (SVM)

# %%
sns.heatmap(confusion_matrix(y_test, X_test_prediction2), annot=True, fmt="d", cmap='Reds')
plt.ylabel('Predicted Values')
plt.xlabel('Actual Values')
plt.title('Confusion Matrix for Support Vector Machine')
plt.show()

print(f'Support Vector Machine Model Accuracy: {accuracy_score(y_test, X_test_prediction2)*100:.2f}%')
print(f'Support Vector Machine Model f1 score: {metrics.f1_score(y_test, X_test_prediction2)*100:.2f}%')
print(f'Support Vector Machine Model MAE: {metrics.mean_absolute_error(y_test, X_test_prediction2)*100:.2f}%')
print(f'Support Vector Machine Model RMSE: {np.sqrt(metrics.mean_squared_error(y_test, X_test_prediction2))*100:.2f}%')
# Out:
# Support Vector Machine Model Accuracy: 86.25%
# Support Vector Machine Model f1 score: 2.94%
# Support Vector Machine Model MAE: 13.75%
# Support Vector Machine Model RMSE: 37.08%

# %% [markdown]
# ### Decision Tree

# %%
sns.heatmap(confusion_matrix(y_test, X_test_prediction3), annot=True, fmt="d", cmap='Greens')
plt.ylabel('Predicted Values')
plt.xlabel('Actual Values')
plt.title('Confusion Matrix for Decision Tree')
plt.show()

print(f'Decision Tree Model Accuracy: {accuracy_score(y_test, X_test_prediction3)*100:.2f}%')
print(f'Decision Tree Model f1 score: {metrics.f1_score(y_test, X_test_prediction3)*100:.2f}%')
print(f'Decision Tree Model MAE: {metrics.mean_absolute_error(y_test, X_test_prediction3)*100:.2f}%')
print(f'Decision Tree Model RMSE: {np.sqrt(metrics.mean_squared_error(y_test, X_test_prediction3))*100:.2f}%')
# Out:
# Decision Tree Model Accuracy: 86.67%
# Decision Tree Model f1 score: 57.89%
# Decision Tree Model MAE: 13.33%
# Decision Tree Model RMSE: 36.51%

# %% [markdown]
# ### K-Nearest Neighbors (KNN)

# %%
sns.heatmap(confusion_matrix(y_test, X_test_prediction4), annot=True, fmt="d", cmap='Purples')
plt.ylabel('Predicted Values')
plt.xlabel('Actual Values')
plt.title('Confusion Matrix for K-Nearest Neighbors')
plt.show()

print(f'K-Nearest Neighbors Model Accuracy: {accuracy_score(y_test, X_test_prediction4)*100:.2f}%')
print(f'K-Nearest Neighbors Model f1 score: {metrics.f1_score(y_test, X_test_prediction4)*100:.2f}%')
print(f'K-Nearest Neighbors Model MAE: {metrics.mean_absolute_error(y_test, X_test_prediction4)*100:.2f}%')
print(f'K-Nearest Neighbors Model RMSE: {np.sqrt(metrics.mean_squared_error(y_test, X_test_prediction4))*100:.2f}%')
# Out:
# K-Nearest Neighbors Model Accuracy: 85.83%
# K-Nearest Neighbors Model f1 score: 27.66%
# K-Nearest Neighbors Model MAE: 14.17%
# K-Nearest Neighbors Model RMSE: 37.64%

# %% [markdown]
# ### Model Comparison

# %%
models = ['Logistic Regression', 'Support Vector Machine', 'Decision Tree', 'K-Nearest Neighbors']
accuracy = [accuracy_score(y_test, X_test_prediction), accuracy_score(y_test, X_test_prediction2), accuracy_score(y_test, X_test_prediction3), accuracy_score(y_test, X_test_prediction4)]
plt.figure(figsize=(10,6))
sns.barplot(x=models, y=accuracy)

for i, val in enumerate(accuracy):
    plt.text(i, val, f'{val:.4f}', ha='center', va='bottom', fontsize=12)
    
plt.title('Model Accuracy Comparison')
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.ylim(0.7, 1.0)
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# It is observed that the Logistic Regression model performs the best on the test set with an accuracy of 86.88%. The model can predict the quality of the wine based on the given features with an accuracy of 86.88%.

# %% [markdown]
# ## Building a Predictive System

# %%
def prediction (data):
    input_data_as_numpy_array= np.asarray(data)

    input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

    prediction = model.predict(input_data_reshaped)
    
    print(f'The result is {prediction[0]}')

    if (prediction[0]== 0):
      print('Bad wine quality')
    else:
      print('Good wine quality')

# %%
input_data = (7.9, 0.545, 0.06, 4.0, 0.087, 27.0, 61.0, 0.9965, 3.36, 0.67, 10.7)
prediction(input_data)
# Out:
# The result is 0
# Bad wine quality

# %%
input_data = (7.9, 0.35, 0.46, 3.6, 0.078, 15.0, 37.0, 0.9973, 3.35, 0.86, 12.8)
prediction(input_data)
# Out:
# The result is 1
# Good wine quality
