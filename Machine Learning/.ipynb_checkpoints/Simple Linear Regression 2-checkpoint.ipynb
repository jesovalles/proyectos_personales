# %%
# importar librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import warnings
warnings.filterwarnings('ignore')

# %%
#Lectura del archivo a analizar
df = pd.read_csv('train.csv')
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
#Gráfica de dispersión
plt.scatter(df["GrLivArea"], df["SalePrice"], alpha=0.5)
plt.xlabel("GrLivArea")
plt.ylabel("SalePrice")
plt.show()

# %%
# Reshape de los datos para que tengan la forma correcta
x = df["GrLivArea"].values.reshape((-1,1))
y = df["SalePrice"].values.reshape((-1,1))

# Dividir los datos en conjuntos de entrenamiento y prueba
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Crear el modelo de regresión lineal
model = linear_model.LinearRegression()

# Entrenar el modelo con los datos de entrenamiento
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Coeficientes del modelo
m = model.coef_[0]
b = model.intercept_

print(f"Pendiente (m) = {m[0]:.2f}")
print(f"Intercepción con el eje Y (b) = {b[0]:.2f}")
print(f"- La pendiente indica que por cada metro cuadrado, el precio aumenta = {m[0]:.2f}")
# Out:
# Pendiente (m) = 102.49
# Intercepción con el eje Y (b) = 24899.75
# - La pendiente indica que por cada metro cuadrado, el precio aumenta = 102.49

# %%
# Realizar predicciones en los datos de prueba
y_pred = model.predict(x_test)

# Calcular los errores
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print(f"Error cuadrático medio (MSE) = {mse:.2f}")
print(f"Coeficiente de determinación (R2) = {r2:.2f}")
print(f"Error Absoluto Medio (MAE) = {mae:.2f}")
# Out:
# Error cuadrático medio (MSE) = 3418946311.18
# Coeficiente de determinación (R2) = 0.55
# Error Absoluto Medio (MAE) = 38341.20

# %%
# Visualización de los resultados
plt.scatter(x_train, y_train, label='Datos de entrenamiento')
plt.scatter(x_test, y_test, color='red', label='Datos de prueba')
plt.plot(x_test, y_pred, color='gold', label='Regresión lineal')
plt.xlabel('GrLivArea')
plt.ylabel('SalePrice')
plt.legend()
plt.show()

print(f"Coeficiente (pendiente): {m[0]:.2f}")
print(f"Interceptor: {b[0]:.2f}")
print(f"Error cuadrático medio (MSE): {mse:.2f}")
print(f"Coeficiente de determinación (R^2): {r2:.2f}")
print(f"Error absoluto medio (MAE) (MAE): {mae:.2f}")
# Out:
# Coeficiente (pendiente): 102.49
# Interceptor: 24899.75
# Error cuadrático medio (MSE): 3418946311.18
# Coeficiente de determinación (R^2): 0.55
# Error absoluto medio (MAE) (MAE): 38341.20

# %%
# funcion para predecir precio de las casas en base a los metros cuadrados
def prediction_function(ft):
    y = round((m[0] * ft + b[0]), 2)
    return y

# %%
ft = 2000
prediction_function(ft)
# Out:
# 229877.67
