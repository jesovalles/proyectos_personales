# %%
# importar librerias
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import warnings
warnings.filterwarnings('ignore')

# %%
#Lectura del archivo a analizar
df = pd.read_csv('train.csv')
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000  ...
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
#Gráfica de dispersión
plt.scatter(df["GrLivArea"], df["SalePrice"], alpha=0.5)
plt.xlabel("Metros cuadrados")
plt.ylabel("Precio de la casa")
plt.show()

# %%
#Creación de modelo de regresión lineal simple y= mx + b
regresion = linear_model.LinearRegression()

#Convertir los datos de la columna GrLivArea a un vector que será la variable independiente
df_GrLivArea = df["GrLivArea"].values.reshape((-1,1))

#Crear modelo en base a la variable independiente para hallar la variable dependiente
modelo = regresion.fit(df_GrLivArea, df["SalePrice"])

# valor de la pendiente
m = modelo.coef_[0]

# valor de la intercepción con el eje Y
b = modelo.intercept_

print(f"Pendiente (m) = {m:.2f}")
print(f"Intercepción con el eje Y (b) = {b:.2f}")
print(f"- La pendiente indica que por cada metro cuadrado, el precio aumenta = {m:.2f}")
# Out:
# Pendiente (m) = 107.13
# Intercepción con el eje Y (b) = 18569.03
# - La pendiente indica que por cada metro cuadrado, el precio aumenta = 107.13

# %%
# Predicciones del modelo
predicciones = modelo.predict(df_GrLivArea)

# Cálculo de errores
mse = mean_squared_error(df["SalePrice"], predicciones)
r2 = r2_score(df["SalePrice"], predicciones)
mae = mean_absolute_error(df["SalePrice"], predicciones)

print(f"Error cuadrático medio (MSE) = {mse:.2f}")
print(f"Coeficiente de determinación (R2) = {r2:.2f}")
print(f"Error Absoluto Medio (MAE) = {mae:.2f}")
# Out:
# Error cuadrático medio (MSE) = 3139843209.67
# Coeficiente de determinación (R2) = 0.50
# Error Absoluto Medio (MAE) = 37638.73

# %%
#Gráfica de dispersión + modelo de regresión lineal simple
plt.scatter(df["GrLivArea"], df["SalePrice"], color="blue", label="Datos", alpha=0.1)
plt.plot(df["GrLivArea"], modelo.predict(df[["GrLivArea"]]), color="black", label="Modelo de regresión lineal")
plt.xlabel("Metros cuadrados")
plt.ylabel("Precio de la casa")
plt.legend()
plt.show()

# %%
# funcion para predecir precio de las casas en base a los metros cuadrados
def prediction_function(ft):
    y = round((m * ft + b), 2)
    return y

# %%
ft = 2000
prediction_function(ft)
# Out:
# 232829.74
